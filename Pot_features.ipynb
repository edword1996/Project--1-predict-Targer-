# %% [markdown]
# <a href="https://colab.research.google.com/github/edword1996/Project--1-predict-Target/blob/master/Pot_features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os,glob
import re
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, explained_variance_score
import scipy as sp
from sklearn.feature_selection import RFE
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split,RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import Ridge, Lasso
import xlrd
from scipy.interpolate import griddata
from sklearn.model_selection import cross_val_score
# %time
import dask
#import dask.dataframe as dd
import dask.array as da
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.48 µs

# %%
# %time  df = pd.read_csv("/content/drive/My Drive/project/filename.csv")
# Out:
# CPU times: user 6.21 s, sys: 370 ms, total: 6.58 s
# Wall time: 7.51 s

# %%
df = df.drop(['Unnamed: 0'],1)
df
# Out:
#                x1        x2        x3        x4  ...  x15  x16   target1   target2
# 0        0.375985  0.267968  0.355502  0.253043  ...  0.0  0.0  0.384615  0.413333
# 1        0.641868  0.329546  0.181139  0.102171  ...  0.0  0.0  0.384615  0.413333
# 2        0.448256  0.238920  0.137017  0.205828  ...  0.0  0.0  0.384615  0.413333
# 3        0.638990  0.435872  0.278504  0.220480  ...  0.0  0.0  0.384615  0.413333
# 4        0.587965  0.369376  0.242203  0.133215  ...  0.0  0.0  0.384615  0.413333
# ...           ...       ...       ...       ...  ...  ...  ...       ...       ...
# 1815691  0.425639  0.423196  0.146331  0.257703  ...  0.0  0.0  0.288462  0.200000
# 1815692  0.360325  0.249947  0.285342  0.175131  ...  0.0  0.0  0.288462  0.200000
# 1815693  0.424200  0.337121  0.223708  0.239812  ...  0.0  0.0  0.288462  0.200000
# 1815694  0.278391  0.246037  0.167082  0.190473  ...  0.0  0.0  0.288462  0.200000
# ...

# %%
plt.figure(figsize=(20, 5))
x = df['x1']
y = df['target1']
plt.scatter(x,y)
plt.title('x1:target1')
plt.ylabel('target ')
plt.xlabel('features')
# Out:
# Text(0.5, 0, 'features')

# %%
plt.figure(figsize=(20, 5))
x = df['x2']
y = df['target1']
plt.scatter(x,y)
plt.title('x2:target1')
plt.ylabel('target ')
plt.xlabel('features')
# Out:
# Text(0.5, 0, 'features')

# %%
x = df['x3']
y = df['target1']
plt.scatter(x,y)
plt.title('x3:target1')
plt.ylabel('target ')
plt.xlabel('features')
# Out:
# Text(0.5, 0, 'features')

# %%
plt.figure(figsize=(20, 5))
x = df['x4']
y = df['target1']
plt.scatter(x,y)
plt.title('x4:target1')
plt.ylabel('target ')
plt.xlabel('features')
# Out:
# Text(0.5, 0, 'features')

# %%
plt.figure(figsize=(20, 5))
x = df['x5']
y = df['target1']
plt.scatter(x,y)
plt.title('x5:target1')
plt.ylabel('target ')
plt.xlabel('features')
# Out:
# Text(0.5, 0, 'features')

# %%
plt.figure(figsize=(20, 5))
x = df['x6']
y = df['target1']
plt.scatter(x,y)
plt.title('x6:target1')
plt.ylabel('target ')
plt.xlabel('features')
# Out:
# Text(0.5, 0, 'features')

# %%
plt.figure(figsize=(20, 5))
x = df['x7']
y = df['target1']
plt.scatter(x,y)
plt.title('x7:target1')
plt.ylabel('target ')
plt.xlabel('features')
# Out:
# Text(0.5, 0, 'features')

# %%
plt.figure(figsize=(20, 5))
x = df['x8']
y = df['target1']
plt.scatter(x,y)
plt.title('x8:target1')
plt.ylabel('target ')
plt.xlabel('features')
# Out:
# Text(0.5, 0, 'features')

# %%
plt.figure(figsize=(20, 5))
x = df['x9']
y = df['target1']
plt.scatter(x,y)
plt.title('x9:target1')
plt.ylabel('target ')
plt.xlabel('features')
# Out:
# Text(0.5, 0, 'features')

# %%
plt.figure(figsize=(20, 5))
x = df['x10']
y = df['target1']
plt.scatter(x,y)
plt.title('x10:target1')
plt.ylabel('target ')
plt.xlabel('features')
# Out:
# Text(0.5, 0, 'features')

# %%
plt.figure(figsize=(20, 5))
x = df['x11']
y = df['target1']
plt.scatter(x,y)
plt.title('x11:target1')
plt.ylabel('target ')
plt.xlabel('features')
# Out:
# Text(0.5, 0, 'features')

# %%
plt.figure(figsize=(20, 5))
x = df['x12']
y = df['target1']
plt.scatter(x,y)
plt.title('x12:target1')
plt.ylabel('target ')
plt.xlabel('features')
# Out:
# Text(0.5, 0, 'features')

# %%
plt.figure(figsize=(20, 5))
x = df['x13']
y = df['target1']
plt.scatter(x,y)
plt.title('x13:target1')
plt.ylabel('target ')
plt.xlabel('features')
# Out:
# Text(0.5, 0, 'features')

# %%
plt.figure(figsize=(20, 5))
x = df['x14']
y = df['target1']
plt.scatter(x,y)
plt.title('x14:target1')
plt.ylabel('target ')
plt.xlabel('features')
# Out:
# Text(0.5, 0, 'features')

# %%
plt.figure(figsize=(20, 5))
x = df['x15']
y = df['target1']
plt.scatter(x,y)
plt.title('x15:target1')
plt.ylabel('target ')
plt.xlabel('features')
# Out:
# Text(0.5, 0, 'features')

# %%
plt.figure(figsize=(20, 5))
x = df['x16']
y = df['target1']
plt.scatter(x,y)
plt.title('x16:target1')
plt.ylabel('target ')
plt.xlabel('features')
# Out:
# Text(0.5, 0, 'features')

# %% [markdown]
# ## **TARGET** **2**

# %%
plt.figure(figsize=(20, 5))
x = df['x1']
y = df['target2']
plt.scatter(x,y)
plt.title('x1:target2')
plt.ylabel('target ')
plt.xlabel('features')
# Out:
# Text(0.5, 0, 'features')

# %%
plt.figure(figsize=(20, 5))
x = df['x2']
y = df['target2']
plt.scatter(x,y)
plt.title('x2:target2')
plt.ylabel('target ')
plt.xlabel('features')
# Out:
# Text(0.5, 0, 'features')

# %%
plt.figure(figsize=(20, 5))
x = df['x3']
y = df['target2']
plt.scatter(x,y)
plt.title('x3:target2')
plt.ylabel('target ')
plt.xlabel('features')
# Out:
# Text(0.5, 0, 'features')

# %%
plt.figure(figsize=(20, 5))
x = df['x4']
y = df['target2']
plt.scatter(x,y)
plt.title('x4:target2')
plt.ylabel('target ')
plt.xlabel('features')
# Out:
# Text(0.5, 0, 'features')

# %%
plt.figure(figsize=(20, 5))
x = df['x5']
y = df['target2']
plt.scatter(x,y)
plt.title('x5:target2')
plt.ylabel('target ')
plt.xlabel('features')
# Out:
# Text(0.5, 0, 'features')

# %%
plt.figure(figsize=(20, 5))
x = df['x6']
y = df['target2']
plt.scatter(x,y)
plt.title('x6:target2')
plt.ylabel('target ')
plt.xlabel('features')
# Out:
# Text(0.5, 0, 'features')

# %%
plt.figure(figsize=(20, 5))
x = df['x7']
y = df['target2']
plt.scatter(x,y)
plt.title('x7:target2')
plt.ylabel('target ')
plt.xlabel('features')
# Out:
# Text(0.5, 0, 'features')

# %%
plt.figure(figsize=(20, 5))
x = df['x8']
y = df['target2']
plt.scatter(x,y)
plt.title('x8:target2')
plt.ylabel('target ')
plt.xlabel('features')
# Out:
# Text(0.5, 0, 'features')

# %%
plt.figure(figsize=(20, 5))
x = df['x9']
y = df['target2']
plt.scatter(x,y)
plt.title('x9:target2')
plt.ylabel('target ')
plt.xlabel('features')
# Out:
# Text(0.5, 0, 'features')

# %%
plt.figure(figsize=(20, 5))
x = df['x10']
y = df['target2']
plt.scatter(x,y)
plt.title('x10:target2')
plt.ylabel('target ')
plt.xlabel('features')
# Out:
# Text(0.5, 0, 'features')

# %%
plt.figure(figsize=(20, 5))
x = df['x11']
y = df['target2']
plt.scatter(x,y)
plt.title('x11:target2')
plt.ylabel('target ')
plt.xlabel('features')
# Out:
# Text(0.5, 0, 'features')

# %%
plt.figure(figsize=(20, 5))
x = df['x12']
y = df['target2']
plt.scatter(x,y)
plt.title('x12:target2')
plt.ylabel('target ')
plt.xlabel('features')
# Out:
# Text(0.5, 0, 'features')

# %%
plt.figure(figsize=(20, 5))
x = df['x13']
y = df['target2']
plt.scatter(x,y)
plt.title('x13:target2')
plt.ylabel('target ')
plt.xlabel('features')
# Out:
# Text(0.5, 0, 'features')

# %%
plt.figure(figsize=(20, 5))
x = df['x14']
y = df['target2']
plt.scatter(x,y)
plt.title('x14:target2')
plt.ylabel('target ')
plt.xlabel('features')
# Out:
# Text(0.5, 0, 'features')

# %%
plt.figure(figsize=(20, 5))
x = df['x15']
y = df['target2']
plt.scatter(x,y)
plt.title('x15:target2')
plt.ylabel('target ')
plt.xlabel('features')
# Out:
# Text(0.5, 0, 'features')

# %%
plt.figure(figsize=(20, 5))
x = df['x16']
y = df['target2']
plt.scatter(x,y)
plt.title('x16:target2')
plt.ylabel('target ')
plt.xlabel('features')
# Out:
# Text(0.5, 0, 'features')
